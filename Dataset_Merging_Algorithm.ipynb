# %%
import os
import shutil
from pathlib import Path
import yaml
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ========= KONFIGURASI =========
dataset_paths = {
    "ds1": "/content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/Fall-Detection-CaucaFall-5",  # ganti sesuai lokasi masing-masing dataset
    "ds2": "/content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/First-Pedestrian-Test-1",
    "ds3": "/content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/Human-Action-Recognition-2000-9",
    "ds4": "/content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/Human-Fall-detection-8",
    "ds5": "/content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5",
}

output_dir = Path("/content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/All-In-One-Dataset")

# Mapping label per dataset
label_map = {
    "ds1": {"fall": "fall", "nofall": "nofall"},
    "ds2": {"Pedestrians": "nofall"},
    "ds3": {"berdiri": "nofall", "berjalan": "nofall", "berlari": "nofall", "jatuh": "fall"},
    "ds4": {"falling": "fall", "sitting": "nofall", "standing": "nofall", "walking": "nofall"},
    "ds5": {
        "fall": "fall", "sit": "nofall", "sleep": "nofall", "standing": "nofall"
        # labels seperti Violence/fire/violence tidak di-include
    }
}

# %%
from google.colab import drive
import os

# 2. Masukkan path folder yang ingin dihitung ukurannya
# Misal folder di MyDrive bernama 'Datasets', maka path-nya:
folder_path = dataset_paths['ds1']

# 3. Fungsi untuk menghitung ukuran folder
def get_folder_size(folder):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(folder):
        for file in filenames:
            fp = os.path.join(dirpath, file)
            total_size += os.path.getsize(fp)
    return total_size

# 4. Fungsi bantu untuk mengubah ukuran byte ke format yang lebih mudah dibaca
def format_size(bytes_size):
    for unit in ['B', 'KB', 'MB', 'GB', 'TB']:
        if bytes_size < 1024:
            return f"{bytes_size:.2f} {unit}"
        bytes_size /= 1024
    return f"{bytes_size:.2f} TB"

# 5. Hitung dan tampilkan ukuran folder
folder_size_bytes = get_folder_size(folder_path)
print(f"Ukuran folder '{folder_path}': {format_size(folder_size_bytes)}")
# Out:
# Ukuran folder '/content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/Fall-Detection-CaucaFall-5': 813.67 MB

# %%
# ========= BANTUAN =========
def get_names(ds_path):
    yaml_path = Path(ds_path) / "data.yaml"
    with open(yaml_path, "r") as f:
        data = yaml.safe_load(f)
    return data["names"]

def get_class_index(label, ds_key):
    mapped = label_map.get(ds_key, {}).get(label)
    if mapped == "fall":
        return 0
    elif mapped == "nofall":
        return 1
    else:
        return None

def process_dataset(ds_key, ds_path, x):
    names = get_names(ds_path)
    print(f'Memproses {ds_path}....')
    if ds_key == 'ds1':
      return 0
    for subset in ["train", "valid", "test"]:
        print(f'Memproses {ds_path}/{subset}....')
        image_dir = Path(ds_path) / subset / "images"
        label_dir = Path(ds_path) / subset / "labels"
        if not image_dir.exists() or not label_dir.exists():
            print(f"Folder {subset} tidak ditemukan di {ds_path}")
            continue

        for label_file in label_dir.glob("*.txt"):
            print(f'Memproses {label_file}')
            with open(label_file, "r") as f:
                lines = f.readlines()

            new_lines = []
            original_name = label_file.stem
            for line in lines:
                parts = line.strip().split()
                if not parts:
                    continue
                class_idx = int(parts[0])
                if class_idx >= len(names):
                    continue
                class_name = names[class_idx]
                new_idx = get_class_index(class_name, ds_key)
                if new_idx is not None:
                    parts[0] = str(new_idx)
                    new_lines.append(" ".join(parts) + "\n")

            if new_lines:
                # Copy image & save label
                for ext in [".jpg", ".png", ".jpeg"]:
                    src_img = image_dir / f"{original_name}{ext}"
                    if src_img.exists():
                        break
                else:
                    continue  # skip if image not found

                dst_img = output_dir / subset / "images" / f"{ds_key}_{original_name}{src_img.suffix}"
                dst_lbl = output_dir / subset / "labels" / f"{ds_key}_{original_name}.txt"

                # 🔧 Perbaikan: pastikan direktori ada
                dst_img.parent.mkdir(parents=True, exist_ok=True)
                dst_lbl.parent.mkdir(parents=True, exist_ok=True)

                shutil.copy(src_img, dst_img)
                with open(dst_lbl, "w") as f:
                    f.writelines(new_lines)
            print(f"Berhasil memproses dataset ke-{x}")
            x += 1
    return x

# %%
# ========= PROSES SEMUA =========
c = 0

for x in ['ds4', 'ds5']:
    ds_key = x
    ds_path = dataset_paths[ds_key]
    c += process_dataset(ds_key, ds_path, c)

# ========= TULIS FILE data.yaml =========
with open(output_dir / "data.yaml", "w") as f:
    f.write(
        "train: train/images\n"
        "val: valid/images\n"
        "test: test/images\n"
        "nc: 2\n"
        "names: ['fall', 'nofall']\n"
    )

print("✅ Dataset berhasil digabungkan ke:", output_dir)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# Berhasil memproses dataset ke-10489
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-105054_jpg.rf.afe10c3a0b5d9b15e677716c86b0d3ff.txt
# Berhasil memproses dataset ke-10490
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/13_jpg.rf.bf2158e851692051de3fcdad97d8ca62.txt
# Berhasil memproses dataset ke-10491
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/A-450-_png_jpg.rf.c51fca68b148e47a0f3e8088cc3bfbbd.txt
# Berhasil memproses dataset ke-10492
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit17_jpg.rf.f4ab6468b15b5ed790354c367cb47fa9.txt
# Berhasil memproses dataset ke-10493
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/00005_png_jpg.rf.cf7381ed2f8787eb1e14a9c34d74fe62.txt
# Berhasil memproses dataset ke-10494
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/standing_8_11_23-15-_jpg.rf.c92102e67cf0489bf6801e96f010f9ea.txt
# Berhasil memproses dataset ke-10495
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2021-08-25-02-44-11_72-76_5_png_jpg.rf.4b68cfcdd1c3efcbfd4a18684190e835.txt
# Berhasil memproses dataset ke-10496
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall002_jpg.rf.bb510d4897ce7ef0205634b8e6cd6f26.txt
# Berhasil memproses dataset ke-10497
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_94_jpg.rf.35d8b660e0cdec01fb477a897d1391c6.txt
# Berhasil memproses dataset ke-10498
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/people-1593-_jpg.rf.33ae09e083855bad56725b6a0f8edf2c.txt
# Berhasil memproses dataset ke-10499
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall_recognition_20210816_354_mp4-0005_jpg.rf.d1a8fb9c91f48d2550abe8b122a6b3d3.txt
# Berhasil memproses dataset ke-10500
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/V_14-0040_jpg.rf.48200ec02e79b50aece271144d7a772e.txt
# Berhasil memproses dataset ke-10501
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_20_jpg.rf.3a6a4787266f1108c1eb37a98be94710.txt
# Berhasil memproses dataset ke-10502
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video_39_jpg.rf.ff29cdd499ed3903df081298058f036b.txt
# Berhasil memproses dataset ke-10503
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/people-1233-_jpg.rf.7f2e5ae600a616366d9a8cfd494e479d.txt
# Berhasil memproses dataset ke-10504
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit126_jpg.rf.069fa8b71f35a9e03fd7c4c734a1d13c.txt
# Berhasil memproses dataset ke-10505
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2033087_jpeg_jpg.rf.977e4a8066451da81f3ac14f7e6f0361.txt
# Berhasil memproses dataset ke-10506
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall-07-cam0-rgb-114_png_jpg.rf.e883b1123038e10c28d7811f96a4f437.txt
# Berhasil memproses dataset ke-10507
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit105_jpg.rf.a0e29cfe0a8f2aec4edc5705eb1daf16.txt
# Berhasil memproses dataset ke-10508
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall_1000038_jpg.rf.113293ee08a76928111b6df447791404.txt
# Berhasil memproses dataset ke-10509
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/WhatsApp-Image-2022-07-31-at-10-36-48-PM_jpeg_jpg.rf.85aa801d30a771368b2232d38e2b4a32.txt
# Berhasil memproses dataset ke-10510
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/14_jpg.rf.7f30ea8bad7ecda14c350c82fddaca1e.txt
# Berhasil memproses dataset ke-10511
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2070674_jpeg_jpg.rf.762607dd3750208410637ce67453ec7b.txt
# Berhasil memproses dataset ke-10512
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2021-08-24-18-39-00_72-54_3_png_jpg.rf.5006e2f485062f8c485d96212bfb827d.txt
# Berhasil memproses dataset ke-10513
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video_635_jpg.rf.c5218706af6c4017ace7c5626a0779bf.txt
# Berhasil memproses dataset ke-10514
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2109364_jpeg_jpg.rf.8f363e5d8c98394ea187518c83fff56f.txt
# Berhasil memproses dataset ke-10515
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit108_jpg.rf.45f8db1ceacbfc5fe9f8dab42097d54c.txt
# Berhasil memproses dataset ke-10516
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/A-345-_png_jpg.rf.de8298c4ae24efa65995cc256d99c4c6.txt
# Berhasil memproses dataset ke-10517
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/WhatsApp-Image-2022-08-02-at-12-29-56-AM-1-_jpeg_jpg.rf.8a3c4881fa611b3a701cd92fea8c7658.txt
# Berhasil memproses dataset ke-10518
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104122_jpg.rf.45164a2abe40b78c65993bade383d6e3.txt
# Berhasil memproses dataset ke-10519
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/people-297-_jpg.rf.a16458b29586e8061a2928c2c00647a1.txt
# Berhasil memproses dataset ke-10520
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit30_jpg.rf.98a4502621f5699c015cd035144e9fa1.txt
# Berhasil memproses dataset ke-10521
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video_xinjishusuosample_BKY_049_20230814_5050_jpg.rf.8ad0ad7bb0528a967c86355642be81ef.txt
# Berhasil memproses dataset ke-10522
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video2_416_jpg.rf.9ba03540da420c6e1fb0ecafcd8cd986.txt
# Berhasil memproses dataset ke-10523
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14243_jpg.rf.0ec8f575031c4dcaf07d8751a0e8279f.txt
# Berhasil memproses dataset ke-10524
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/00027_png_jpg.rf.03a6899aa1e26208212498fa23eef36e.txt
# Berhasil memproses dataset ke-10525
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_15_jpg.rf.021f0577a163612108d709f0e8aa92b3.txt
# Berhasil memproses dataset ke-10526
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/B-218-_png_jpg.rf.0dd126da9226ab531b7f2aa05e961521.txt
# Berhasil memproses dataset ke-10527
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/bionta-1205-01_64_jpg.rf.45d4a1dea5700ec9c84c2085d46bee55.txt
# Berhasil memproses dataset ke-10528
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2018-07-11T13_42_44-307820_png_jpg.rf.4a073f86f61f16030e03c5c8baabd46f.txt
# Berhasil memproses dataset ke-10529
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/v1_55_jpg.rf.7ecf937f434ba0ff521e78f216b9a59f.txt
# Berhasil memproses dataset ke-10530
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sitting_8_11_23-42-_jpg.rf.ee902e24b8c39fbb1c166a1bff33be21.txt
# Berhasil memproses dataset ke-10531
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall049_jpg.rf.9fe4d5d582156c4a76b4880443351c85.txt
# Berhasil memproses dataset ke-10532
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/chute05_7_jpg.rf.1b5549496a042de3de7368d261847d4c.txt
# Berhasil memproses dataset ke-10533
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2085265_jpeg_jpg.rf.ba0c771afbb7a80af349b522bd153e80.txt
# Berhasil memproses dataset ke-10534
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/33_jpg.rf.865206655d5ca3c56da28e7c5f7efcd8.txt
# Berhasil memproses dataset ke-10535
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/people-197-_jpg.rf.d721e9c6d64863bfefd1d6ad28a7a846.txt
# Berhasil memproses dataset ke-10536
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/22_jpg.rf.388a2ef7343a053a3e3d4c7da02a3977.txt
# Berhasil memproses dataset ke-10537
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/standing_8_11_23-22-_jpg.rf.553d929d72a39c285125dada8b6bedcf.txt
# Berhasil memproses dataset ke-10538
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video_xinjishusuosample_BKY_049_20230807_3870_jpg.rf.ddf2fc3dbbba66d211f43b38dc3e98ac.txt
# Berhasil memproses dataset ke-10539
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/1975700_jpeg_jpg.rf.f1b8dd94b0c7dda6481e8b9a34b33ed2.txt
# Berhasil memproses dataset ke-10540
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104540_jpg.rf.5552d8161e6bbde0911863964848877c.txt
# Berhasil memproses dataset ke-10541
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit106_jpg.rf.603a914f6752928e3c048a72a0ed5f3b.txt
# Berhasil memproses dataset ke-10542
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2bf80d4d1b20dd9be731fbe71745fbf3_jpg.rf.d28a0ea5dec4db5d1501ebd730811318.txt
# Berhasil memproses dataset ke-10543
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video_420_jpg.rf.838c64e02846d6c659f981e31a9a83f5.txt
# Berhasil memproses dataset ke-10544
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104334_jpg.rf.6ad0a6d89f584880a94f39e16314fa19.txt
# Berhasil memproses dataset ke-10545
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104703_jpg.rf.94bee1df3524d4aae95702556f4d1927.txt
# Berhasil memproses dataset ke-10546
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/people-1383-_jpg.rf.68159a203fe805ba8d7c0b2a78918dd6.txt
# Berhasil memproses dataset ke-10547
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_201_jpg.rf.bdbf93fe6da0eced5b6c94e3ad63a3a5.txt
# Berhasil memproses dataset ke-10548
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104852_jpg.rf.a20c48d6813ec11c8b6dc2d287ca95bc.txt
# Berhasil memproses dataset ke-10549
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit13_jpg.rf.e2c89a05a880a0185e6d0b9f05bc6915.txt
# Berhasil memproses dataset ke-10550
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/not-fallen026_jpg.rf.bc0138ba275ec3f42937a1ab10088459.txt
# Berhasil memproses dataset ke-10551
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit11_jpg.rf.ff2efed91cbfd260b32270b293b0abd5.txt
# Berhasil memproses dataset ke-10552
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam13451_jpg.rf.8f5615cb581665b0165edda911137880.txt
# Berhasil memproses dataset ke-10553
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/582a92c72813f51cdfd12c39ec4d47a8_jpg.rf.8f812d0ea5d332e52f4cbaae6d4f7610.txt
# Berhasil memproses dataset ke-10554
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit117_jpg.rf.96e1f8258ed946ded4d8736ab89805de.txt
# Berhasil memproses dataset ke-10555
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/v2_29_jpg.rf.7c2f62958dd4ee3c063d13c0d372737e.txt
# Berhasil memproses dataset ke-10556
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104211_jpg.rf.21c6a52bc97531ec1add65d67a154214.txt
# Berhasil memproses dataset ke-10557
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/C-135-_png_jpg.rf.712256f584b70d2aeb3f70e905036402.txt
# Berhasil memproses dataset ke-10558
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit109_jpg.rf.750ba33fd1bc068302ffe436d07a1ff3.txt
# Berhasil memproses dataset ke-10559
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2021-08-25-03-35-46_72-69_3_png_jpg.rf.1ee228722e1b1c277060791e80d785d4.txt
# Berhasil memproses dataset ke-10560
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/bionta-1205-01_336_jpg.rf.b02ffc14a6c559a40279455b50cff704.txt
# Berhasil memproses dataset ke-10561
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/25_jpg.rf.7707ea250d574226d65fe20c3ea3572f.txt
# Berhasil memproses dataset ke-10562
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2018-07-11T13_41_37-164170_png_jpg.rf.b91303ad9c77c01b9359d42fbca54f44.txt
# Berhasil memproses dataset ke-10563
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2021-08-25-02-33-57_72-94_3_png_jpg.rf.bbd84f221ad60bdf94cf088f37f8d4ac.txt
# Berhasil memproses dataset ke-10564
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/people-4003-_jpg.rf.f54e556b59665db085e77e19db7ece08.txt
# Berhasil memproses dataset ke-10565
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2058352_jpeg_jpg.rf.28e3348812142b614742cd58b8ca977c.txt
# Berhasil memproses dataset ke-10566
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/25_jpg.rf.5782b40ff95c28f00cbcfdbe7d21760c.txt
# Berhasil memproses dataset ke-10567
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2018-07-04T12_06_24-811038_png_jpg.rf.3cf642652743f4e461c0c3204dc3581c.txt
# Berhasil memproses dataset ke-10568
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/A-210-_png_jpg.rf.7b3ae16ed490a31b6a2af8f4ba80ce42.txt
# Berhasil memproses dataset ke-10569
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2021-09-20-04-46-51_72-54_4_png_jpg.rf.7417e6d8defcebedbc20d222b0ecbd10.txt
# Berhasil memproses dataset ke-10570
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall203_jpg.rf.aa041b7606cdfe171eb8c257f2c7ff34.txt
# Berhasil memproses dataset ke-10571
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/bionta-1204-02_332_jpg.rf.d37c1bed605d7cd223e38c02d1fcd035.txt
# Berhasil memproses dataset ke-10572
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video0-039_jpeg_jpg.rf.77da10c6ae62b8ceea14bd34490b9b79.txt
# Berhasil memproses dataset ke-10573
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/standing_8_11_23-25-_jpg.rf.7462b5febbf8f34673513f186003f319.txt
# Berhasil memproses dataset ke-10574
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit35_jpg.rf.7880d2b4ebfe8c6c47df100d39483ab8.txt
# Berhasil memproses dataset ke-10575
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/not-fallen121_jpg.rf.b9f075f82cfe1ed263e28bcbc9b5bdee.txt
# Berhasil memproses dataset ke-10576
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/204211_110171_4521_jpg.rf.eaeae8c4850fb33cc0afafec260a76d8.txt
# Berhasil memproses dataset ke-10577
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/not-fallen020_png_jpg.rf.78b0b9129d9e352c7fe839a1367f4986.txt
# Berhasil memproses dataset ke-10578
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall023_jpg.rf.e7985d2292dee416981339454b8c0178.txt
# Berhasil memproses dataset ke-10579
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit128_jpg.rf.460e65775504206f832b6cc64775a40e.txt
# Berhasil memproses dataset ke-10580
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/standing_8_11_23-63-_jpg.rf.67210e81dbf188d0132d0696402ffe89.txt
# Berhasil memproses dataset ke-10581
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/9_jpg.rf.d8c4e33b3a0c2f13b88a74b46c469db4.txt
# Berhasil memproses dataset ke-10582
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2021-09-20-11-39-48_72-54_3_png_jpg.rf.ac3ec8ee64afa4a40114d036a9a46b68.txt
# Berhasil memproses dataset ke-10583
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2021-09-20-11-55-16_72-54_3_png_jpg.rf.bf74c9dc6701677bd9dd2d9f18995543.txt
# Berhasil memproses dataset ke-10584
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall158_jpg.rf.70bea52e410df5b09bac5c2f94efbb2e.txt
# Berhasil memproses dataset ke-10585
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14253_jpg.rf.a2be0dc3e6c7010d1c841a8414d49934.txt
# Berhasil memproses dataset ke-10586
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/1410372_520_images_jpg.rf.90111e08565d5f15b9ed70bdb8b51c88.txt
# Berhasil memproses dataset ke-10587
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall110_jpg.rf.97ee32b759eb97855cad60dd367259c6.txt
# Berhasil memproses dataset ke-10588
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Type1_Video4_frame79_jpg.rf.0f456790679cd84737536a48fc841469.txt
# Berhasil memproses dataset ke-10589
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-105002_jpg.rf.08995aec2c105c31ed014608c480a28e.txt
# Berhasil memproses dataset ke-10590
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2021-08-25-03-15-16_72-71_2_png_jpg.rf.792b6c1f7b73a79e16e8e5055c1873b0.txt
# Berhasil memproses dataset ke-10591
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_313_jpg.rf.dc2e7820dd52a6b0a799adad6709fab7.txt
# Berhasil memproses dataset ke-10592
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/42_jpg.rf.a9ca60c5a2404ba340289e03087bbfdc.txt
# Berhasil memproses dataset ke-10593
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit27_jpg.rf.12bf7341e2e847d962d35e6a130b627c.txt
# Berhasil memproses dataset ke-10594
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14557_jpg.rf.dd4706c4c1ee050f0567b24904d690e0.txt
# Berhasil memproses dataset ke-10595
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_53_jpg.rf.49b474c4af35e24b60e166055165a171.txt
# Berhasil memproses dataset ke-10596
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2018-07-04T12_06_23-760667_png_jpg.rf.2347bb802530e76f77cde3a5c518774c.txt
# Berhasil memproses dataset ke-10597
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall_1000081_jpg.rf.6789ad0f43e8acee35e535c9091300cf.txt
# Berhasil memproses dataset ke-10598
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/B-25-_png_jpg.rf.3dcd47db90afeddf29a5c0da32ca2372.txt
# Berhasil memproses dataset ke-10599
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104438_jpg.rf.96a9880636ccf3c69d8c796ba5f603f5.txt
# Berhasil memproses dataset ke-10600
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_131_jpg.rf.498ef74ddcf5f0c4ac2f8dcd27f3a961.txt
# Berhasil memproses dataset ke-10601
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2226503_jpeg_jpg.rf.33ddbdf947376838833779405badd475.txt
# Berhasil memproses dataset ke-10602
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/9_jpg.rf.a712236880afd00aa2a3d1e2b91e10cd.txt
# Berhasil memproses dataset ke-10603
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/1899270_jpeg_jpg.rf.ff058bf1093567e653601e7e41448d50.txt
# Berhasil memproses dataset ke-10604
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104643_jpg.rf.90e60c778b9d43fbd59c09758f9a02d6.txt
# Berhasil memproses dataset ke-10605
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/34_jpg.rf.92c677995a2671f46b994867e29fe0fa.txt
# Berhasil memproses dataset ke-10606
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2225746_jpeg_jpg.rf.482a24ad908a518f4dd37480bcbf6794.txt
# Berhasil memproses dataset ke-10607
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit109_jpg.rf.4c703afcd91b01aae54af488964403ea.txt
# Berhasil memproses dataset ke-10608
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104241_jpg.rf.2b59f3226c04eac0fcc44b489d3cc23b.txt
# Berhasil memproses dataset ke-10609
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-from-2022-07-18-00-12-41_jpg.rf.5602e8503248e0545b78ce83ac812f72.txt
# Berhasil memproses dataset ke-10610
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam13819_jpg.rf.814fc141d1a6c21f5f5aaf5f56277b4d.txt
# Berhasil memproses dataset ke-10611
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_138_jpg.rf.60ecf5cc47f33e343fc1318a36c71ca2.txt
# Berhasil memproses dataset ke-10612
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit124_jpg.rf.3f817d217436afcd53871e0e39f7be21.txt
# Berhasil memproses dataset ke-10613
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2207789_jpeg_jpg.rf.fd6718b62e8ab531bd5ee5958009f2ba.txt
# Berhasil memproses dataset ke-10614
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/A-479-_png_jpg.rf.e4a06e408c315cba3abc56c61a325790.txt
# Berhasil memproses dataset ke-10615
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/34_jpg.rf.183b3753b0ea28633387af631f6a4bee.txt
# Berhasil memproses dataset ke-10616
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14047_jpg.rf.b6b28276174e9866f31f52336fae2f2a.txt
# Berhasil memproses dataset ke-10617
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/00009_png_jpg.rf.f3643dfbbfd9b05cad72ea16f39838e3.txt
# Berhasil memproses dataset ke-10618
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video2_493_jpg.rf.5729d805482a804b3d0663a5b0d1901d.txt
# Berhasil memproses dataset ke-10619
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104806_jpg.rf.93993712f09c8c0e0d2ca981790de780.txt
# Berhasil memproses dataset ke-10620
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/standing_8_11_23-39-_jpg.rf.b0573d48801b3f5f40f1d90a9767c810.txt
# Berhasil memproses dataset ke-10621
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14503_jpg.rf.eeb44e08fc2510f5406df0002eed3639.txt
# Berhasil memproses dataset ke-10622
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/WhatsApp-Video-2022-07-11-at-2-0780_jpg.rf.49092fd8437f469804a4e28d5fdd4e6f.txt
# Berhasil memproses dataset ke-10623
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/standing_8_11_23-15-_jpg.rf.2418bc3c8f57be2c939ed82c512e9013.txt
# Berhasil memproses dataset ke-10624
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/00001_png_jpg.rf.6c104c2e8161a48396bb1f85ddd56c6b.txt
# Berhasil memproses dataset ke-10625
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2021-08-23-17-47-05_72-69_4_png_jpg.rf.2838e252f5cc0cbb1c4165c2bd907959.txt
# Berhasil memproses dataset ke-10626
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/standing_8_11_23-25-_jpg.rf.6258d12f728369e9fc2020bee2c13a7a.txt
# Berhasil memproses dataset ke-10627
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Type4_case11_frame673_jpg.rf.dabeb8461d545c41e8f3a378e323280e.txt
# Berhasil memproses dataset ke-10628
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104906_jpg.rf.060b4d7538b944f13218a8afc49f3ee3.txt
# Berhasil memproses dataset ke-10629
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14503_jpg.rf.f59c2c544cb9a16deba2f13f0386f6e1.txt
# Berhasil memproses dataset ke-10630
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Img_1301_jpg.rf.b17bf032070676f73b8bc17ae8cf2097.txt
# Berhasil memproses dataset ke-10631
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/v2_29_jpg.rf.11c84ef2e46a2e5470c747be551dee7c.txt
# Berhasil memproses dataset ke-10632
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14389_jpg.rf.e50789000d66a1724479c7db42853d90.txt
# Berhasil memproses dataset ke-10633
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/V_405_F39_jpg.rf.517253608d077371a235b109b284190a.txt
# Berhasil memproses dataset ke-10634
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14265_jpg.rf.bafdd7740229d9ef79196be5bb8ce00b.txt
# Berhasil memproses dataset ke-10635
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104348_jpg.rf.e85826362443d72d6fbf3ce5c4d9c387.txt
# Berhasil memproses dataset ke-10636
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104628_jpg.rf.f354b621027daad756d2aea45e9feb3c.txt
# Berhasil memproses dataset ke-10637
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/v1_60_jpg.rf.739c597121a6dcf4bcbebf6c98c52240.txt
# Berhasil memproses dataset ke-10638
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/1978186_jpeg_jpg.rf.b98a0f618e453c5723c0b99f982ee581.txt
# Berhasil memproses dataset ke-10639
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104059_jpg.rf.c4dceb361bf77d1811b21b6f6b8f5ab5.txt
# Berhasil memproses dataset ke-10640
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit13_jpg.rf.455e5a66d9e9e836c786948eddd5c55f.txt
# Berhasil memproses dataset ke-10641
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104556_jpg.rf.0c9f45e7042ee741b780789c6dc812f4.txt
# Berhasil memproses dataset ke-10642
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/v1_10_jpg.rf.1e42115c0842f47653eaf7028cbd6b8c.txt
# Berhasil memproses dataset ke-10643
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-105353_jpg.rf.fef9cdecc3e75fbea8f75674b2ba2a6f.txt
# Berhasil memproses dataset ke-10644
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/v1_29_jpg.rf.044e9d2a7d25d09f7e582268e719671b.txt
# Berhasil memproses dataset ke-10645
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/4a8786214a3fa8b33e5c31964e5b2fcb_jpg.rf.e97cca168914d0991df657fe76eeed22.txt
# Berhasil memproses dataset ke-10646
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/not-fallen026_png_jpg.rf.6c6fb95d521db701b7b0e453c798a76e.txt
# Berhasil memproses dataset ke-10647
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/B-188-_png_jpg.rf.49a9689f36f19abe36aaab01d74111a8.txt
# Berhasil memproses dataset ke-10648
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2021-08-26-02-59-40_72-69_3_png_jpg.rf.6223b240d0d86bcffa141576a5940404.txt
# Berhasil memproses dataset ke-10649
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam13495_jpg.rf.d02f2c0f8211d93f5543938a11baa248.txt
# Berhasil memproses dataset ke-10650
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_131_jpg.rf.cfa31ca54a2aa255da80170890e03128.txt
# Berhasil memproses dataset ke-10651
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/V_420_F39_jpg.rf.85ea10709d78369dda87a4572c485522.txt
# Berhasil memproses dataset ke-10652
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/restaurants-et-les-gens-sur-la-rue-a-montmartre-paris-ile-de-france-france-f666kj_jpg.rf.b38a5037c3831bcf474100f7593a8c04.txt
# Berhasil memproses dataset ke-10653
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/pho-1205-01_59_jpg.rf.7443173e2d2dc6e323f1c2c524288ddb.txt
# Berhasil memproses dataset ke-10654
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/A-316-_png_jpg.rf.8144e08c87fd96dfc093674412a4ce0d.txt
# Berhasil memproses dataset ke-10655
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/V_420_F84_jpg.rf.f1acebe788fd7a1f1d8d5c6cdfff951c.txt
# Berhasil memproses dataset ke-10656
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/off_violence29_jpg.rf.3910d5015d153e9a91b4814ba5956596.txt
# Berhasil memproses dataset ke-10657
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/WhatsApp-Video-2022-07-11-at-1-0860_jpg.rf.91041c33304c12155f64a709f58436f9.txt
# Berhasil memproses dataset ke-10658
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-from-2022-07-18-00-26-40_jpg.rf.bb64a6f74b0f00370016589f9ab48537.txt
# Berhasil memproses dataset ke-10659
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/A-100-_png_jpg.rf.c490c53fb694a8e1b7b438819b8213ac.txt
# Berhasil memproses dataset ke-10660
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video0-014_jpeg_jpg.rf.11b16cf61a5ef83cc709f6a2b5d90577.txt
# Berhasil memproses dataset ke-10661
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/9_jpg.rf.cec97b0063059319a7f80559443dc6ac.txt
# Berhasil memproses dataset ke-10662
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/1923372_jpeg_jpg.rf.6ba6b92e53131082a403db6c927df147.txt
# Berhasil memproses dataset ke-10663
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14498_jpg.rf.8e1c4ebb66245fbe61fe7af22e376b83.txt
# Berhasil memproses dataset ke-10664
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video_492_jpg.rf.4da25144b4d1fe2df2af2c5027a22e64.txt
# Berhasil memproses dataset ke-10665
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2113544_jpeg_jpg.rf.fc7eb179ed46bc2cffcf38a4d83e07c9.txt
# Berhasil memproses dataset ke-10666
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Type1_Video4_frame84_jpg.rf.af3f8b5c2d850fc2bf016a4dd31395ef.txt
# Berhasil memproses dataset ke-10667
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video2_543_jpg.rf.a1bd34309aa5d1c1dc741735cb7a176c.txt
# Berhasil memproses dataset ke-10668
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104256_jpg.rf.c0b4addee2919f044013b9e435541b44.txt
# Berhasil memproses dataset ke-10669
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video_xinjishusuosample_BKY_049_20230807_4690_jpg.rf.971027643f8560c76f00e36852be89c7.txt
# Berhasil memproses dataset ke-10670
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit110_jpg.rf.db79bdcd63fff7fec76d06e9472772be.txt
# Berhasil memproses dataset ke-10671
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14510_jpg.rf.22ac0befeeee398decc65f6ed0a69481.txt
# Berhasil memproses dataset ke-10672
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/standing_8_11_23-75-_jpg.rf.1e72040c6399e81ee11fe8867d8bd7f6.txt
# Berhasil memproses dataset ke-10673
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video1-014_jpeg_jpg.rf.8aed50d8ed5b6426d0a826be2cd7fab0.txt
# Berhasil memproses dataset ke-10674
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit117_jpg.rf.5105dc5fcdaf982e1e961ed7fa2c244b.txt
# Berhasil memproses dataset ke-10675
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video_251_jpg.rf.ea26601958782fc70de343d4ab754a7c.txt
# Berhasil memproses dataset ke-10676
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam13913_jpg.rf.355cfb4342bb319ea187f7cb53999008.txt
# Berhasil memproses dataset ke-10677
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14375_jpg.rf.875c337b6407bfce878fa80d446487c9.txt
# Berhasil memproses dataset ke-10678
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall101_jpg.rf.71f7438c74e2ac17a03e8173035e823a.txt
# Berhasil memproses dataset ke-10679
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/people-1436-_jpg.rf.919847540ebd1e4b5561906a69fd5d3f.txt
# Berhasil memproses dataset ke-10680
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall_1000040_jpg.rf.a88a332f0ce6ace01900b75b935dda1f.txt
# Berhasil memproses dataset ke-10681
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/chute11_38_jpg.rf.6b2bfc94de892e6375bf386cbc79ccc4.txt
# Berhasil memproses dataset ke-10682
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104540_jpg.rf.1a90d1a74ff327fd7a7f71a48fc27674.txt
# Berhasil memproses dataset ke-10683
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/standing_8_11_23-63-_jpg.rf.626178d59cf9a4386102079429badd60.txt
# Berhasil memproses dataset ke-10684
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104431_jpg.rf.67aec8dfe56c9f80c602b5958baed660.txt
# Berhasil memproses dataset ke-10685
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2182017_jpeg_jpg.rf.92ee208f22d3638acfdee1c91aafff5d.txt
# Berhasil memproses dataset ke-10686
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14435_jpg.rf.0506117f8c82f4cdb4b10f557c22a87e.txt
# Berhasil memproses dataset ke-10687
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/v1_74_jpg.rf.7ca950166245b4863076ff4f03b87795.txt
# Berhasil memproses dataset ke-10688
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104356_jpg.rf.8d987e8ba883711b720ebd2fea2f4efd.txt
# Berhasil memproses dataset ke-10689
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/A-131-_png_jpg.rf.e42ce510293e0495a83ee63880ad40c7.txt
# Berhasil memproses dataset ke-10690
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/1930365_jpeg_jpg.rf.51556e8a25586833e3b865be6336fb89.txt
# Berhasil memproses dataset ke-10691
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall018_jpg.rf.6df43e54807ef0c1e0bb827bcba16c1b.txt
# Berhasil memproses dataset ke-10692
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall198_jpg.rf.219ee45f71299581b26f6ae10fdc7b9f.txt
# Berhasil memproses dataset ke-10693
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-105445_jpg.rf.0bc93dc7950911cb20b0d27d0c9e8d8a.txt
# Berhasil memproses dataset ke-10694
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall-08-cam0-rgb-091_png_jpg.rf.4d726a909254574eab00b2f784df8dcc.txt
# Berhasil memproses dataset ke-10695
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104739_jpg.rf.411b85549599766887efea961a04c1fa.txt
# Berhasil memproses dataset ke-10696
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104921_jpg.rf.f4b5de643442055f4b30e8fe1aefe495.txt
# Berhasil memproses dataset ke-10697
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit50_jpg.rf.4e6a731957ee3234bd7b10a93be60e22.txt
# Berhasil memproses dataset ke-10698
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104431_jpg.rf.8f714cf57b5bbb043d46bcf77fd3c3b1.txt
# Berhasil memproses dataset ke-10699
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/v1_27_jpg.rf.74fd5ca16adc04d0611d8251774895da.txt
# Berhasil memproses dataset ke-10700
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Type1_Video4_frame100_jpg.rf.d70771b831dd4a5327def5c3ef443e1a.txt
# Berhasil memproses dataset ke-10701
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/C-119-_png_jpg.rf.0c724f5d1f2fc650fe5cc9d8372466c4.txt
# Berhasil memproses dataset ke-10702
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/v1_8_jpg.rf.da9322132325250886851a9d9ead64b4.txt
# Berhasil memproses dataset ke-10703
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/video1-018_jpeg_jpg.rf.277e24e9c924056bcd462397adddc953.txt
# Berhasil memproses dataset ke-10704
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2018-07-04T12_04_21-992390_png_jpg.rf.08feb63a8a7ac66a061f99c34c999c3f.txt
# Berhasil memproses dataset ke-10705
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/A-369-_png_jpg.rf.1f3a692b29b91e9434a488e83b70ba27.txt
# Berhasil memproses dataset ke-10706
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-105205_jpg.rf.a7d23db0c77a6faa396d9b73d0e3f8ec.txt
# Berhasil memproses dataset ke-10707
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/v2_21_jpg.rf.6246e158130ae38a94bf565467c32da7.txt
# Berhasil memproses dataset ke-10708
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/C-59-_png_jpg.rf.5e897484b153a7e137315a5c9fd47f25.txt
# Berhasil memproses dataset ke-10709
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/WhatsApp-Video-2022-07-11-at-1-0130_jpg.rf.676b6e459db037a86e34a23655e9d4d2.txt
# Berhasil memproses dataset ke-10710
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104806_jpg.rf.1b3266474c6539178da7237ee4357959.txt
# Berhasil memproses dataset ke-10711
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104444_jpg.rf.349d14e910da90403676328a87a386d7.txt
# Berhasil memproses dataset ke-10712
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/WhatsApp-Video-2022-07-11-at-2-1240_jpg.rf.27d4204fe06c0fffe72f42cef0074458.txt
# Berhasil memproses dataset ke-10713
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/A-397-_png_jpg.rf.51e72e32d93ca21ba5d70e73731d224a.txt
# Berhasil memproses dataset ke-10714
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/2108251_jpeg_jpg.rf.9915572efb7260c1539a22af04845abb.txt
# Berhasil memproses dataset ke-10715
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/sit11_jpg.rf.b3c0621dd014f21855cb62469a221b6a.txt
# Berhasil memproses dataset ke-10716
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_58_jpg.rf.d8914d564c0044e81d04c2c84ec5e4fb.txt
# Berhasil memproses dataset ke-10717
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/image_47_jpg.rf.aa14be75c8632a0d544f29890541c9c6.txt
# Berhasil memproses dataset ke-10718
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/Screenshot-2022-08-09-104431_jpg.rf.16a569e0e99d21c7f30c0d92c14a86f4.txt
# Berhasil memproses dataset ke-10719
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall-02-cam0-rgb-079_png_jpg.rf.431d6a939cdac69a9907d57585e68856.txt
# Berhasil memproses dataset ke-10720
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/fall110_jpg.rf.d4c43ce44dd900fdb40139d3d9662905.txt
# Berhasil memproses dataset ke-10721
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/chute18_12_jpg.rf.cca9205be5bde4d54e44b369f6e2cbdd.txt
# Berhasil memproses dataset ke-10722
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/cam14393_jpg.rf.12d9947871ee945c9d3fdd2f437ec953.txt
# Berhasil memproses dataset ke-10723
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/train/labels/B-106-_png_jpg.rf.b9e41ddfaf28e57e369b45df38fdefcd.txt
# Berhasil memproses dataset ke-10724
# ...
# Berhasil memproses dataset ke-12909
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/sit49_jpg.rf.c35e37e4cc32bf78aee3a271cfa1dc04.txt
# Berhasil memproses dataset ke-12910
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam14342_jpg.rf.857219152b9c6b356783aefeb95d25ae.txt
# Berhasil memproses dataset ke-12911
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/C-241-_png_jpg.rf.f7cac603a57ec2254bdb782bf6c72aee.txt
# Berhasil memproses dataset ke-12912
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/1908562_jpeg_jpg.rf.e2ee5ced1d77de5a757018ceeb0e7166.txt
# Berhasil memproses dataset ke-12913
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/sit10_jpg.rf.e577662af0ad8b8159daf977c9b34eb9.txt
# Berhasil memproses dataset ke-12914
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/yt-FaLcnRHPEeM-0015_jpg.rf.71b6c7b28277402606e42d1b6d9d92ee.txt
# Berhasil memproses dataset ke-12915
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/v1_34_jpg.rf.892047944db7b3dedd9a8d98c2e6ad04.txt
# Berhasil memproses dataset ke-12916
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam14553_jpg.rf.89ce541155e6fee087385e2eba5a88d4.txt
# Berhasil memproses dataset ke-12917
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam14382_jpg.rf.2ffebba9abdf5455633cddf41aa4e13b.txt
# Berhasil memproses dataset ke-12918
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/sit66_jpg.rf.a61e7b23ff2d416c9e255a755d9ea98b.txt
# Berhasil memproses dataset ke-12919
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2134730_jpeg_jpg.rf.55135f5aae5091cea8be3770f6ef0e65.txt
# Berhasil memproses dataset ke-12920
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam13913_jpg.rf.eae14f345c577f7f41337f019af19f8b.txt
# Berhasil memproses dataset ke-12921
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/v2_9_jpg.rf.13c309489409705c163d3b8c365aee8a.txt
# Berhasil memproses dataset ke-12922
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/v1_3_jpg.rf.930fb1ff1af2156a6ea88a342d27811d.txt
# Berhasil memproses dataset ke-12923
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/C-242-_png_jpg.rf.7f46daf1a4e3aaea1ad1447468bcb1f1.txt
# Berhasil memproses dataset ke-12924
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2136599_jpeg_jpg.rf.5952e003c70b1b36764e06c5253bef14.txt
# Berhasil memproses dataset ke-12925
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/1978836_jpeg_jpg.rf.34797b57736e0791b3179eefbe1182aa.txt
# Berhasil memproses dataset ke-12926
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/A-318-_png_jpg.rf.477fa20a620204bdbdd86160c66197dd.txt
# Berhasil memproses dataset ke-12927
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam14397_jpg.rf.754c941426665f2fed2ba66a00554f89.txt
# Berhasil memproses dataset ke-12928
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/Img_170_jpg.rf.60c10367e2df025b69b30b248ff6caca.txt
# Berhasil memproses dataset ke-12929
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/V_306_F150_jpg.rf.06c1a9664b3d7267bae3d12472f1ef2f.txt
# Berhasil memproses dataset ke-12930
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam14597_jpg.rf.1cc857295a93b379f6a5cf8fd11e6de3.txt
# Berhasil memproses dataset ke-12931
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam14341_jpg.rf.43657c50a4a9a94a2647a80185150f77.txt
# Berhasil memproses dataset ke-12932
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/B-170-_png_jpg.rf.316c39b567b159d03f7b9d986224f0ce.txt
# Berhasil memproses dataset ke-12933
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/sit32_jpg.rf.aa3b13bd4d7159d85f5a5d8e446705e7.txt
# Berhasil memproses dataset ke-12934
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam13544_jpg.rf.73212bb7ead9f65b046043e80e5814cd.txt
# Berhasil memproses dataset ke-12935
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/v1_0_jpg.rf.6ad2b725bee214b139890e7e8e23a9f5.txt
# Berhasil memproses dataset ke-12936
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/sit32_jpg.rf.90d9b229a98216d3599e3940b0b68a51.txt
# Berhasil memproses dataset ke-12937
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/1984826_jpeg_jpg.rf.26cc6ad8612769b948479659e169a333.txt
# Berhasil memproses dataset ke-12938
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/19_jpg.rf.79d076a4a55fe65e355f6667978c5050.txt
# Berhasil memproses dataset ke-12939
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/istockphoto-1149920121-640x640_jpg.rf.90d9fabce170ec77f502f206051cefe8.txt
# Berhasil memproses dataset ke-12940
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/B-202-_png_jpg.rf.6efbdd55f0e73adb3094d77c61db1aa7.txt
# Berhasil memproses dataset ke-12941
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2021-09-20-16-28-51_72-54_3_png_jpg.rf.908d0be63e9885a0d5359a9783ab1a5e.txt
# Berhasil memproses dataset ke-12942
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/vlc-record-2023-10-18-1_372_jpg.rf.6172dee527a575b05a6d0086ebe04811.txt
# Berhasil memproses dataset ke-12943
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/mumbai-indiatardeojehangir-boman-behram-roadhindmatarestaurant-restaur4ants-EWEFE7_jpg.rf.6f567f63911cc55711a2646f7aa3de7d.txt
# Berhasil memproses dataset ke-12944
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2176228_jpeg_jpg.rf.ff457e93f91d7f5ab86fa1e267147d26.txt
# Berhasil memproses dataset ke-12945
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/v1_3_jpg.rf.df551b57286c34d61e35f01e87906b88.txt
# Berhasil memproses dataset ke-12946
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/B-69-_png_jpg.rf.2ea7b1ef27de6b367986f15b62543edb.txt
# Berhasil memproses dataset ke-12947
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/video_xinjishusuosample_BKY_200_20230807_4390_jpg.rf.221b09b90afaa0986d29a96b24f9c684.txt
# Berhasil memproses dataset ke-12948
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/B-121-_png_jpg.rf.224082683e7308e3f27469e7e446d202.txt
# Berhasil memproses dataset ke-12949
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/les-gens-de-cafe-tortoni-sur-l-avenida-de-mayo-dans-le-centre-ville-dans-le-quartier-de-microcentro-montserrat-capitale-buenos-aires-argentine-mx2e60_jpg.rf.1a82bf8e479fca48ed3f3590b664a1c6.txt
# Berhasil memproses dataset ke-12950
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam13194_jpg.rf.e1163b5c902470b8fe7e30a4f3b53642.txt
# Berhasil memproses dataset ke-12951
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/v2_26_jpg.rf.76d523cf03df189f76d5e477d74330f9.txt
# Berhasil memproses dataset ke-12952
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2021-09-21-06-50-55_72-54_3_png_jpg.rf.85330775fdf845c0bb1544d931269dc9.txt
# Berhasil memproses dataset ke-12953
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/38_jpg.rf.a2f6332e77f0cf836f3bfc03110e84e0.txt
# Berhasil memproses dataset ke-12954
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2138186_jpeg_jpg.rf.8937d8a8b571618361402f7465a06db5.txt
# Berhasil memproses dataset ke-12955
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2021-08-24-03-51-07_72-94_5_png_jpg.rf.43e495c35edc43400fcaa66c60e8213f.txt
# Berhasil memproses dataset ke-12956
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2018-07-04T12_04_22-792559_png_jpg.rf.063aecf320394c75f47dfcfb4bf06b4f.txt
# Berhasil memproses dataset ke-12957
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/6e78533afba2711fc39dfceec9614825_jpg.rf.3d6be36c78219341b85a0c8276be29e2.txt
# Berhasil memproses dataset ke-12958
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/1926371_jpeg_jpg.rf.f05388ac77a350b4538d8d0091a7552e.txt
# Berhasil memproses dataset ke-12959
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/1922329_jpeg_jpg.rf.90a725950c00c91af16b82445c794096.txt
# Berhasil memproses dataset ke-12960
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2021-08-24-03-09-50_72-94_5_png_jpg.rf.f62869f12013497301e46f7b318f193d.txt
# Berhasil memproses dataset ke-12961
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/A-144-_png_jpg.rf.b19285a1c51874e4e3f1a6cdf9be9f73.txt
# Berhasil memproses dataset ke-12962
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam14482_jpg.rf.5bf6d14a55c01ee4514a10b94efd0a4d.txt
# Berhasil memproses dataset ke-12963
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2029089_jpeg_jpg.rf.1e56d98f7b36b411b79b682a4b32ad4f.txt
# Berhasil memproses dataset ke-12964
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/1908452_jpeg_jpg.rf.6fc5b735f87721ee7792c18d9f507687.txt
# Berhasil memproses dataset ke-12965
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/A-15-_png_jpg.rf.6ad4c9abdcb5b109b7c5a9712fb9b2ce.txt
# Berhasil memproses dataset ke-12966
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2021-09-20-04-10-43_72-54_3_png_jpg.rf.6541d25c9b1739aab082435636f7ed4e.txt
# Berhasil memproses dataset ke-12967
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam13422_jpg.rf.a7efd3d0c5fe76a4692b3e6d14b03e23.txt
# Berhasil memproses dataset ke-12968
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2018-07-04T12_08_23-656912_png_jpg.rf.f8a5c968b24dd874a529a1441bc3af8a.txt
# Berhasil memproses dataset ke-12969
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/Img_1278_jpg.rf.e846d967de0542fd2b03c06012764205.txt
# Berhasil memproses dataset ke-12970
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/340_png_jpg.rf.f6410c57049f249cf25c930b6fb0b219.txt
# Berhasil memproses dataset ke-12971
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2097639_jpeg_jpg.rf.881c2152aed414cf2dda0517de381465.txt
# Berhasil memproses dataset ke-12972
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2176106_jpeg_jpg.rf.ac4343b5924b5ce81291f3276c49e7f2.txt
# Berhasil memproses dataset ke-12973
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/Screenshot-2022-08-09-105048_jpg.rf.b9246167e86b6ae3f6a9ad526b0e5685.txt
# Berhasil memproses dataset ke-12974
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/18_jpg.rf.705f273b219c3c7f08aea0711e32acfd.txt
# Berhasil memproses dataset ke-12975
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/v1_71_jpg.rf.664989155b1b3e36a202dd577a295e8d.txt
# Berhasil memproses dataset ke-12976
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2060774_jpeg_jpg.rf.82b0ea746899aa6b958b15f9425754e9.txt
# Berhasil memproses dataset ke-12977
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2021-09-21-04-21-13_72-54_3_png_jpg.rf.1d5ae6d84bcc10ed0d1f7e7f00ca1cca.txt
# Berhasil memproses dataset ke-12978
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/34_png_jpg.rf.75a15935e75f23f03a777c1ef6a3ec54.txt
# Berhasil memproses dataset ke-12979
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam14501_jpg.rf.f54c703b40543bd72a7de6c2d83aca42.txt
# Berhasil memproses dataset ke-12980
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/cam14518_jpg.rf.e9f7b6b3ec1c8af8819b3b977caca1ff.txt
# Berhasil memproses dataset ke-12981
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/yt-4Y2MYZoXnw4-0115_jpg.rf.c754ba807ee1e6056a3318e65135df34.txt
# Berhasil memproses dataset ke-12982
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/video_xinjishusuosample_BKY_200_20230807_3930_jpg.rf.191d4275b7d074d430a4076887312248.txt
# Berhasil memproses dataset ke-12983
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/B-201-_png_jpg.rf.7d21312936940f55fd407756d712ff85.txt
# Berhasil memproses dataset ke-12984
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/2021-08-25-03-30-38_72-76_3_png_jpg.rf.3eedb37ac8200188c06b3a0a1d0befdd.txt
# Berhasil memproses dataset ke-12985
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/A-60-_png_jpg.rf.0152ff49028b76de19cb6cff8a61bb4a.txt
# Berhasil memproses dataset ke-12986
# Memproses /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/exceptional-situations-5/test/labels/1978851_jpeg_jpg.rf.428b15fdd22a27a7dcfcd3b24d17f691.txt
# Berhasil memproses dataset ke-12987
# ✅ Dataset berhasil digabungkan ke: /content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/All-In-One-Dataset

# %%
import os
def count_files(path):
    return len([f for f in os.listdir(path) if f.endswith('.jpg') or f.endswith('.png') or f.endswith('.txt')])

print('============List Dataset============')
splits = ['train', 'valid', 'test']
split_count = {}
temp = '/content/All-In-One-Dataset'
total = 0
for split in splits:
    img_path = f"{temp}/{split}/images"
    lbl_path = f"{temp}/{split}/labels"
    split_count[split] = count_files(img_path)
    total += split_count[split]

for i, split in enumerate(splits):
    print(f"{split.upper()} - Images: {split_count[i]}, Percentage : {float(split_count[i])/float(total):.2f}")
print(f'Total =', total, '\n')
# Out:
# ============AIO Dataset============
# TRAIN - Images: 29272, Labels: 29272
# VALID - Images: 4723, Labels: 4723
# TEST - Images: 982, Labels: 982
# Total = 34977

# %%
import shutil

# Ganti dengan path folder dataset yang digunakan
folder_path = '/content/drive/MyDrive/Skripton_(Skripsi_Marathon)/Dataset/All-In-One-Dataset'
output_zip = '/content/AIO_Dataset.zip'  # hasil zip akan disimpan di workspace Colab

# Kompres folder jadi ZIP
shutil.make_archive('/content/AIO_Dataset', 'zip', folder_path)

# Unduh file ZIP
files.download(output_zip)

# %% [markdown]
# # Rombak Lanjutan

# %%
#Mendownload Dataset AIO
# Install gdown jika belum ada
# !pip install -q gdown

import gdown
import zipfile
import os

def downextract(url = [], extract_to = '/content', nama = 'default'):
  # Ganti dengan File ID dari Google Drive

  for i, j in enumerate(url):
    # Download file dari Google Drive
    gdown.download(j, f'dataset_{nama}_{i+1}.zip', quiet=False)

    # Ekstraksi zip setelah unduh
    os.makedirs(extract_to, exist_ok=True)  # Buat folder tujuan jika belum ada
    with zipfile.ZipFile(f'dataset_{nama}_{i+1}.zip', 'r') as zip_ref:
        zip_ref.extractall(extract_to)

  print(f"✅ File berhasil diunduh dan diekstrak ke: {extract_to}")

# %%
downextract(['https://drive.google.com/uc?id=1PPWhdbidrjbpa-jImb77eDnYkvBsQSnv','https://drive.google.com/uc?id=1O_7ZzkS4FbRk2lY_7pvHAMnc_TOwQ6V5'], nama='AIO')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1PPWhdbidrjbpa-jImb77eDnYkvBsQSnv
# From (redirected): https://drive.google.com/uc?id=1PPWhdbidrjbpa-jImb77eDnYkvBsQSnv&confirm=t&uuid=2897e322-ce11-4def-9105-cc542fb747e4
# To: /content/dataset_AIO_1.zip
# 100%|██████████| 1.67G/1.67G [00:40<00:00, 40.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1O_7ZzkS4FbRk2lY_7pvHAMnc_TOwQ6V5
# From (redirected): https://drive.google.com/uc?id=1O_7ZzkS4FbRk2lY_7pvHAMnc_TOwQ6V5&confirm=t&uuid=bd68d68d-4318-45fd-8ac7-ee1f7f449cce
# To: /content/dataset_AIO_2.zip
# 100%|██████████| 56.3M/56.3M [00:01<00:00, 29.9MB/s]
# ✅ File berhasil diunduh dan diekstrak ke: /content

# %%
import os
import shutil
import random

# Path dataset YOLO
dataset_path = "/content/All-In-One-Dataset"  # ganti sesuai dataset

valid_img_dir = os.path.join(dataset_path, "valid", "images")
valid_lbl_dir = os.path.join(dataset_path, "valid", "labels")

test_img_dir = os.path.join(dataset_path, "test", "images")
test_lbl_dir = os.path.join(dataset_path, "test", "labels")

# Pastikan folder test ada
os.makedirs(test_img_dir, exist_ok=True)
os.makedirs(test_lbl_dir, exist_ok=True)

# Ambil daftar gambar di valid
img_files = [f for f in os.listdir(valid_img_dir) if f.endswith((".jpg", ".png", ".jpeg"))]

# Pastikan jumlah cukup
if len(img_files) < 900:
    raise ValueError(f"Hanya ada {len(img_files)} gambar di valid, tidak cukup untuk pindahkan 900.")

# Ambil 900 gambar secara acak
img_files_to_move = random.sample(img_files, 900)

count_moved = 0
for img_file in img_files_to_move:
    lbl_file = os.path.splitext(img_file)[0] + ".txt"

    src_img = os.path.join(valid_img_dir, img_file)
    src_lbl = os.path.join(valid_lbl_dir, lbl_file)

    dst_img = os.path.join(test_img_dir, img_file)
    dst_lbl = os.path.join(test_lbl_dir, lbl_file)

    # pindahkan gambar
    if os.path.exists(src_img):
        shutil.move(src_img, dst_img)

    # pindahkan label (kalau ada)
    if os.path.exists(src_lbl):
        shutil.move(src_lbl, dst_lbl)

    count_moved += 1

print(f"Selesai! Total file gambar yang dipindahkan: {count_moved}")
# Out:
# Selesai! Total file gambar yang dipindahkan: 900

# %%
import os
def count_files(path):
    return len([f for f in os.listdir(path) if f.endswith('.jpg') or f.endswith('.png') or f.endswith('.txt')])

print('============List Dataset============')
splits = ['train', 'valid', 'test']
split_count = {}
temp = '/content/All-In-One-Dataset'
total = 0
for split in splits:
    img_path = f"{temp}/{split}/images"
    lbl_path = f"{temp}/{split}/labels"
    split_count[split] = count_files(img_path)
    total += split_count[split]

for i, split in enumerate(splits):
    print(f"{split.upper()} - Images: {split_count[split]}, Percentage : {float(split_count[split])/float(total):.2f}")
print(f'Total =', total, '\n')
# Out:
# ============List Dataset============
# TRAIN - Images: 29272, Percentage : 0.84
# VALID - Images: 3823, Percentage : 0.11
# TEST - Images: 1882, Percentage : 0.05
# Total = 34977

# %%
# !zip -r -q NEW_AIO_3.zip /content/All-In-One-Dataset
# !cp /content/NEW_AIO_3.zip /content/drive/MyDrive/SKRIPSI_2106020_Renaldy_Azhari_Imaduddin/Dataset
